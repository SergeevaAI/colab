# %% [markdown]
# <a href="https://colab.research.google.com/github/SergeevaAI/colab/blob/main/lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Без имени.png](data:image/png;base64,...)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_01.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergehewa02@mail.ru


x = float(input("Введите число x: "))

if x >= 0:
    f = sqrt(x)+x**2
else:
    f = 1 / x

print("f =", round(f, 2))
# Out:
# Введите число x: -10
# f = -0.1

# %% [markdown]
# № 4.2.2
#
# Определите максимальное и минимальное значения из двух различных целых чисел.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_02.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergehewa02@mail.ru
a1 = int(input("Введите первое число: "))
a2 = int(input("Введите второе число: "))

# Переменная 'a_min' должна содержать минимум, 'a_max' - максимум
if a1 > a2:
  a_max = a1
  a_min = a2
else:
  a_max = a2
  a_min = a1
print("Максимум: {}, минимум: {}".format(a_max, a_min))
# Out:
# Введите первое число: 1
# Введите второе число: 2
# Максимум: 2, минимум: 1

# %% [markdown]
# № 4.2.3
#
# Вася пытается высунуть голову в форточку размерами a и b см. Приняв условно, что его голова - круглая диаметром d см, определите, сможет ли Вася сделать это. Для прохождения головы в форточку необходим зазор в 1 см. с каждой стороны.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_03.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergehewa02@mail.ru


a = float(input("Ширина форточки: "))
b = float(input("Высота форточки: "))
d = float(input("Диаметр головы: "))

# Введенные числа должны быть положительными, если так - осуществляем
# расчет, иначе выводим "Проверьте ввод"
if a > 0 and b > 0 and d > 0:
    fix = 1  # Зазор
    if (a + fix) > d and (b + fix) > d:
      print("Да")
    else:
      print("Нет") 
        
else:
    print("Проверьте ввод")
# Out:
# Ширина форточки: 5
# Высота форточки: 6
# Диаметр головы: 6
# Нет

# %% [markdown]
# № 4.2.4
#
# Известны год и номер месяца сегодняшнего дня, а также год и номер месяца рождения человека (нумерация месяцев с 1: январь - 1 и т.д.). Определите возраст человека (число полных лет).

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_04.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergehewa02@mail.ru


year_today = int(input("Введите текущий год: "))
month_today = int(input("Введите текущий месяц: "))

year = int(input("Введите год рождения: "))
month = int(input("Введите месяц рождения: "))

# Считается, введенные значения находятся в допустимых пределах,и
# что 'month_today' >= 'month' (проверять значения не нужно)
# Результат необходимо записать в переменную 'age'
age = year_today - year
if month_today < month:
  age -= 1
print("Число полных лет: ", age)
# Out:
# Введите текущий год: 2017
# Введите текущий месяц: 5
# Введите год рождения: 2000
# Введите месяц рождения: 1
# Число полных лет:  17

# %% [markdown]
# № 4.2.5
#
# Дана точка с целыми ненулевыми координатами (x;y). Определить номер четверти координатной плоскости, которой она принадлежит.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_05.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergeevaai036@mgpu.ru


x = int(input("Введите координату x: "))
y = int(input("Введите координату y: "))

if x>0 and y>0:
    print("1-я четверть")
elif x<0 and y>0:
  print("2-я четверть")
elif x<0 and y<0:
  print("3-я четверть")
else:  
  print("4-я четверть")
# Out:
# Введите координату x: 5
# Введите координату y: 7
# 1-я четверть

# %% [markdown]
# № 4.2.6
#
# Даны вещественные числа a, b, c (a≠0).
#
# Решите уравнение ax2+bx+c=0. При выводе значений оставьте 1 знак после запятой.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_06.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergeevaai036@mgpu.ru


a = float(input())
b = float(input())
c = float(input())

# Расчет дискриминанта
d = b**2-4*a*c

# Вывод решения в зависимости от значения дискриминанта
if d>0:
  x1= (-b+sqrt(d))/2*a
  x2= (-b-sqrt(d))/2*a
  print("x1 = ", round(x1, 1), "x2 = ", round(x2, 1))
elif d < 0:
  print("Решений нет") 
else:
  x = -b/(2*a)
  print("x = ", round(x, 1))
# При выводе значений оставьте 1 знак после запятой
# Out:
# 1
# 2
# 1
# x =  -1.0

# %% [markdown]
# № 4.2.7
#
# Дана непустая последовательность целых чисел, оканчивающаяся нулем. Найти сумму и количество введенных чисел.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_07.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergeevaai036@mgpu.ru

nums_sum = 0  # сумма
nums_count = 0  # количество

x = int(input("Введите 1-е число: "))
i = 1
while x != 0:
    i += 1
    nums_count += 1
    nums_sum += x
    x = int(input("Введите {} -е число: ".format(i)))
     

print("Сумма = ", nums_sum)
print("Количество = ", nums_count)
# Out:
# Введите 1-е число: 1
# Введите 2 -е число: 2
# Введите 3 -е число: 3
# Введите 4 -е число: 4
# Введите 5 -е число: 0
# Сумма =  10
# Количество =  4

# %% [markdown]
# ![111.jpg](data:image/jpeg;base64,...)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_08.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergeevaai036@mgpu.ru


n = int(input("n = "))
a = 0
while n >= a:
  print(a)
  a+= 5
# Out:
# n = 10
# 0
# 5
# 10

# %% [markdown]
# ![112.jpg](data:image/jpeg;base64,...)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_09.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergeevaai036@mgpu.ru


a = float(input("a = "))
n = 1
x_sum = n
while x_sum <= a:
  n+= 1
  x_sum += 1/n
print("n = ", n)
# Удалите комментарий и допишите код
# Out:
# a = 1.5
# n =  3

# %% [markdown]
# № 4.2.10
#
# Дано натуральное число. Определите сумму и количество его цифр.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_10.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergeevaai036@mgpu.ru

n_sum = 0
n_count = 0
n = int(input("n = "))
while n!=0:
  n_sum += n%10
  n_count += 1
  n = n//10
print("Сумма = ", n_sum)
print("Количество = ", n_count)
# Out:
# n = 12345
# Сумма =  15
# Количество =  5

# %% [markdown]
# № 4.2.12
#
# Даны целые числа a и b(a может быть больше b). Напечатайте:
#
# числа от минимального до максимального в строчку (разделяя пробелом);
#
# числа от максимального до минимального «столбиком».

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_12.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergeevaai036@mgpu.ru


a = int(input("a = "))
b = int(input("b = "))
if a>b:
  i1=b
  for i in range(a-b+1):
    print(i1, end=' ')
    i1+=1
  print(end='\n')
  i1=a
  for i in range(a-b+1):
    print(i1)
    i1-=1

else:
  i1=a
  for i in range(b-a+1):
    print(i1, end=' ')
    i1+=1
  print(end='\n')
  i1=b
  for i in range(b-a+1):
    print(i1)
    i1-=1
# Out:
# a = 1
# b = 5
# 1 2 3 4 5
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# ![1111111.jpg](data:image/jpeg;base64,...)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_13.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergeevaai036@mgpu.ru


a = int(input("a = "))
b = int(input("b = "))
n_sum = 0
n_mult = 1
k = 0
b1 = 1
c = 0
for i in range(b-a+1):
  n_sum+=a
  n_mult*=a
  k+=1
  if a%2!=0:
    b1*=a
    c+=1
  a+=1
n_avg = round(n_sum/k, 2)
n_avg_geom = round(b1**(1/c), 2)
print("Сумма =", n_sum)
print("Произведение =", n_mult)
print("Среднее арифметическое = {}".format(n_avg))
print("Среднее геометрическое нечетных чисел = {}".format(n_avg_geom))
# Out:
# a = 1
# b = 5
# Сумма = 15
# Произведение = 120
# Среднее арифметическое = 3.0
# Среднее геометрическое нечетных чисел = 2.47

# %% [markdown]
# ![222.jpg](data:image/jpeg;base64,...)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_14.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergeevaai036@mgpu.ru


s = float(input(" Пробег за 1-й день (км.) = "))
p = float(input("На сколько увеличивает пробег (%) = "))
total = s
for i in range(9):
  i+=1
  s+=s*(p/100)
  total+=s
  print("Пробег за {}-й день: ".format(i), round(s, 1), "км.")
total = round(total, 1)
print("Суммарный пробег: {:.1f} км.".format(total))
# Out:
#  Пробег за 1-й день (км.) = 5
# На сколько увеличивает пробег (%) = 10
# Пробег за 1-й день:  5.5 км.
# Пробег за 2-й день:  6.0 км.
# Пробег за 3-й день:  6.7 км.
# Пробег за 4-й день:  7.3 км.
# Пробег за 5-й день:  8.1 км.
# Пробег за 6-й день:  8.9 км.
# Пробег за 7-й день:  9.7 км.
# Пробег за 8-й день:  10.7 км.
# Пробег за 9-й день:  11.8 км.
# Суммарный пробег: 79.7 км.

# %% [markdown]
# № 4.2.15
#
# Известна масса каждого предмета в кг., загружаемого в грузовик. Определить, возможна ли перевозка груза, если грузоподъемность грузовика равна p кг.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_15.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergeevaai036@mgpu.ru


p = float(input("Грузоподъемность грузовика (кг.) = "))
n = int(input("Количество предметов = "))
total = 0
for i in range(n):
  m = float(input("Масса {}-го предмета (кг.) = ".format(i)))
  total+=m
if total<=p:
  print("Да")
else:
  print("Нет")
# Out:
# Грузоподъемность грузовика (кг.) = 10
# Количество предметов = 2
# Масса 0-го предмета (кг.) = 3
# Масса 1-го предмета (кг.) = 3
# Да

# %% [markdown]
# № 4.2.16
#
# В области несколько районов. Заданы площади, засеваемые пшеницей (га.), и средняя урожайность (ц/га) в каждом районе.
#
# Определите количество пшеницы, собранное по области. При выводе вещественных результатов оставьте один знак после запятой.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_16.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergeevaai036@mgpu.ru


n = int(input("Количество районов = "))
total = 0
for i in range(n):
  p = float(input("Площадь {}-го района (га) = ".format(i)))
  r = float(input("Урожайность в {}-м районе (ц/га.) = ".format(i)))
  total+=p*r
total = round(total, 1)
print("Собрано пшеницы: {} ц.".format(total))
# Out:
# Количество районов = 3
# Площадь 0-го района (га) = 4
# Урожайность в 0-м районе (ц/га.) = 2
# Площадь 1-го района (га) = 7
# Урожайность в 1-м районе (ц/га.) = 3
# Площадь 2-го района (га) = 9
# Урожайность в 2-м районе (ц/га.) = 4
# Собрано пшеницы: 65.0 ц.

# %% [markdown]
# № 4.2.17
#
# Решите задачу № 4.2.7, организовав бесконечный цикл, который бы прерывался при выполнении условия, используя оператор break.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_17.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergeevaai036@mgpu.ru


nums_sum = 0  # сумма
nums_count = 0  # количество

x = int(input("Введите 1-е число: "))
i = 1
while True:
    i += 1
    nums_count += 1
    nums_sum += x
    x = int(input("Введите {} -е число: ".format(i)))
    if x==0:
      break 

print("Сумма = ", nums_sum)
print("Количество = ", nums_count)
# Out:
# Введите 1-е число: 1
# Введите 2 -е число: 2
# Введите 3 -е число: 3
# Введите 4 -е число: 4
# Введите 5 -е число: 0
# Сумма =  10
# Количество =  4

# %% [markdown]
# № 4.2.18
#
# Предложение, введенное с клавиатуры, содержит слова из гласных и согласных букв кириллицы (регистр может быть различный), а также пробелы.
#
# Определите количество гласных и согласных букв в предложении. Для пропуска пробелов используйте оператор continue.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_18.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergeevaai036@mgpu.ru


sentence = input("Введите предложение: ")

count_gl = 0  # Кол-во гласных
count_sogl = 0  # Кол-во согласных

for i in sentence:
  i = i.lower()
  if i in 'ауоыиэяюёе':
    count_gl += 1
  elif i==' ':
    continue
  else:
     count_sogl +=1


print("Кол-во букв в предложении: гласных - {}, согласных - {}".format(count_gl, count_sogl))
# Out:
# Введите предложение: Программирование
# Кол-во букв в предложении: гласных - 7, согласных - 9

# %% [markdown]
# № 4.2.19
#
# Выведите на экран (в строку) все целые числа от a до b, кратные некоторому числу c.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_19.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergeevaai036@mgpu.ru


a = int(input("a = "))
b = int(input("b = "))
c = int(input("c = "))

i1=b
for i in range(a-b+1):
  if i1%c==0:

    print(i1, end=' ')
  i1+=1
# Out:
# a = 1
# b = 10
# c = 2
# 2 4 6 8 10

# %% [markdown]
# ![333.jpg](data:image/jpeg;base64,...)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_20.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergeevaai036@mgpu.ru


n = int(input("n = "))
for i in range(100, 1000):
  a=i//100
  b=(i//10)%10
  c=i%10
  if (a+b+c)==n:
   print(i, end=' ')
# Out:
# n = 3
# 102 111 120 201 210 300

# %% [markdown]
# № 4.2.21
#
# Известно количество учеников в классе и их рост (см.); рост мальчиков условно задан отрицательными числами. Определите средний рост мальчиков и средний рост девочек.
#
# При выводе вещественных результатов оставьте один знак после запятой.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_21.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergeevaai036@mgpu.ru

import math
n = int(input("n = "))

r_sr_m = 0.0
r_sr_d = 0.0
r_m = 0
r_d = 0
k1 = 0
k2 = 0
for i in range(n):
  r = int(input("Рост {}-го ученика = ".format(i+1)))
  if r<0:
    r_m+=r
    k1+=1
  else:
    r_d+=r
    k2+=1
r_sr_m = r_m/k1
r_sr_m = abs(r_sr_m)
r_sr_m = round(r_sr_m, 1)
r_sr_d = round(r_d/k2, 1)
print("Средний рост мальчиков: {:.1f}".format(r_sr_m))
print("Средний рост девочек: {:.1f}".format(r_sr_d))
# Out:
# n = 5
# Рост 1-го ученика = 150
# Рост 2-го ученика = -150
# Рост 3-го ученика = 160
# Рост 4-го ученика = 170
# Рост 5-го ученика = 180
# Средний рост мальчиков: 150.0
# Средний рост девочек: 165.0

# %% [markdown]
# № 4.2.22
#
# Даны n вещественных чисел. Определите максимальное и минимальное из них.
#
# При выводе вещественных результатов оставьте два знака после запятой.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_22.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergeevaai036@mgpu.ru


n = int(input("n = "))
c = a
a_max = None
a_min = None

for i in range(n):
  a = float(input("{}-е число = ".format(i+1)))
  if a>c:
    a_max = a
    a_min = c
  else:
    a_max = c
    a_min = a
  c = a
a_max = round(a_max, 2)
a_min = round(a_min, 2)
print("Максимум: {:.2f}".format(a_max))
print("Минимум: {:.2f}".format(a_min))
# Out:
# n = 4
# 1-е число = 6.2
# 2-е число = 3.8
# 3-е число = 1.1
# 4-е число = 9.66
# Максимум: 9.66
# Минимум: 1.10

# %% [markdown]
# № 4.2.23
#
# Дано натуральное число n. Определите, является ли оно членом последовательности Фибоначчи.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_23.
#
# Выполнила: Сергеева А. И.
# Группа: АДЭУ-211
# E-mail: sergeevaai036@mgpu.ru
a1 = 0
a2 = 1
n = int(input("n = "))
for i in range(3, n):
  c=a1+a2
  a1 = a2
  a2 = c
print("Является" if n==c else "Не является")
# Out:
# n = 8
# Является
