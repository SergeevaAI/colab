# %% [markdown]
# <a href="https://colab.research.google.com/github/SergeevaAI/colab/blob/main/1_%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class First:
  color = "red"
  def out(self):
    print(self.color + "!")
obj1 = First()   
obj2 = First()
print(obj1.color)
print(obj2.color)
obj1.out()
obj2.out()
# Out:
# red
# red
# red!
# red!

# %%
class Second:
  color = "red"
  form = "circle"
  def changecolor(self, newcolor):
    self.color = newcolor
  def changeform(self, newform):
    self.form = newform

obj1 = Second()
obj2 = Second()
print(obj1.color, obj1.form)
print(obj2.color, obj2.form)
obj1.changecolor("green")
obj2.changecolor("blue")
obj2.changeform("oval")
print(obj1.color, obj1.form)
print(obj2.color, obj2.form)
# Out:
# red circle
# red circle
# green circle
# blue oval

# %%
class YesInit:
  def __init__(self, one="noname", two="nonametoo"):
    self.fname=one
    self.sname=two
obj1=YesInit('Sasha', 'Tu')
obj2=YesInit()
obj3=YesInit('Spartak')
obj4=YesInit(two="Hrry")
print(obj1.fname, obj1.sname)
print(obj2.fname, obj2.sname)
print(obj3.fname, obj3.sname)
print(obj4.fname, obj4.sname)
# Out:
# Sasha Tu
# noname nonametoo
# Spartak nonametoo
# noname Hrry

# %%
class fruits:
  def __init__(self, w, n=0):
    self.what=w
    self.numbers=n
f1=fruits('apple', 150)
f2=fruits('pineapple')
print(f1.what, f1.numbers)
print(f2.what, f2.numbers)
class fruits:
  def __init__(self, w, n=0):
    self.what=w
    self.numbers=n   
f1=fruits('apple', 150)
f2=fruits('pineapple')    
print(f1.what, f1.numbers)
print(f2.what, f2.numbers)
# Out:
# apple 150
# pineapple 0
# apple 150
# pineapple 0

# %%
class Building:
  def __init__(self, w, c, n = 0):
    self.what = w
    self.color = c
    self.numbers = n
    self.mwhere(n)
  def mwhere(self, n):
    if n<= 0:
      self.where = "отсутствуют"
    elif 0 < n < 100:
      self.where = "малый склад"
    else:
      self.where = "основной склад"
  def plus(self, p):
    self.numbers = self.numbers + p
    self.mwhere(self.numbers)
  def minus(self, m):
    self.numbers = self.numbers - m
    self.mwhere(self.numbers) 
m1 = Building("доски", "белые", 50)  
m2 = Building("доски", "коричневые", 300)
m3 = Building("кирпичи", "белые")  
print(m1.what, m1.color, m1.where)
print(m2.what, m2.color, m2.where)
print(m3.what, m3.color, m3.where)
# Out:
# доски белые малый склад
# доски коричневые основной склад
# кирпичи белые отсутствуют

# %%
class Things:
  def __init__(self, n, t):
    self.namething = n
    self.total = t
th1 = Things("table", 5)   
th2 = Things("computer", 7)
print(th1.namething, th1.total) 
print(th2.namething, th2.total)
th1.color = "green"
th2.color = "black"
print(th1.color) 
print(th2.color)
# Out:
# table 5
# computer 7
# green
# black

# %% [markdown]
# ![11.jpg](data:image/jpeg;base64,...)

# %%
class First:
  color = "red"
  def out(self):
    print(self.color + "!")
obj1 = First()   
obj2 = First()
print(obj1.color)
print(obj2.color)
obj1.out()
obj2.out()
# Out:
# red
# red
# red!
# red!

# %%
class Second:
  color = "red"
  form = "circle"
  number = "one"
  def changecolor(self, newcolor):
    self.color = newcolor
  def changeform(self, newform):
    self.form = newform
  def changenumber(self, newnumber):   
    self.number = newnumber
obj1 = Second()
obj2 = Second()
obj3 = Second()
print(obj1.color, obj1.form)
print(obj2.color, obj2.form)
obj1.changecolor("green")
obj2.changecolor("blue")
obj2.changeform("oval")
obj3.changecolor("blue")
obj3.changeform("oval")
obj3.changenumber("two")
print(obj1.color, obj1.form)
print(obj2.color, obj2.form)
print(obj3.color, obj3.form, obj3.number)
# Out:
# red circle
# red circle
# green circle
# blue oval
# blue oval two

# %%
class Second:
  color = "red"
  form = "circle"
  def changecolor(self, newcolor):
    self.color = newcolor
class First:     
  def changeform(self, newform):
    self.form = newform
obj1 = Second()
obj2 = First() 
obj2.changeform("oval") 
obj1.changecolor(obj2.form)

# %%
class Table:
  def __init__(self, l, w, h):
    self.long=l
    self.width=w
    self.height=h
  def outing(self):
    print(self.long, self.width, self.height)
class Kitchen(Table):
  def howplaces(self, n):
    if n<2:
      print("It is not kitchen table")
    else:
      self.places=n
  def outplaces(self):
    print(self.places)
t_room1=Kitchen(2, 1, 0.5)
t_room1.outing()
t_room1.howplaces(5)
t_room1.outplaces()
t_room2=Table(1, 3, 0.7)
t_room2.outing()
# Out:
# 2 1 0.5
# 5
# 1 3 0.7

# %% [markdown]
# ![12.jpg](data:image/jpeg;base64,...)

# %%
class Building:
  def __init__(self, w, c, n = 0):
    self.what = w
    self.color = c
    self.numbers = n
    self.mwhere(n)
  def mwhere(self, n):
    if n<= 0:
      self.where = "отсутствуют"
    elif 0 < n < 100:
      self.where = "малый склад"
    else:
      self.where = "основной склад"
  def plus(self, p):
    self.numbers = self.numbers + p
    self.mwhere(self.numbers)
  def minus(self, m):
    self.numbers = self.numbers - m
    self.mwhere(self.numbers) 
m1 = Building("доски", "белые", 50)  
m2 = Building("доски", "коричневые", 300)
m3 = Building("кирпичи", "белые")  
print(m1.what, m1.color, m1.where)
print(m2.what, m2.color, m2.where)
print(m3.what, m3.color, m3.where)
# Out:
# доски белые малый склад
# доски коричневые основной склад
# кирпичи белые отсутствуют

# %%
class Fobia:
  def __init__(self, one, two, three):
    self.figure = one
    self.color = two
    self.numbers = three
a1 = Fobia("овал", "белый", 1)  
a2 = Fobia("квадрат", "чёрный", 2)
a3 = Fobia("ромб", "серый", 3) 
print(a1.figure, a1.color, a1.numbers)
print(a2.figure, a2.color, a2.numbers)
print(a3.figure, a3.color, a3.numbers)
# Out:
# овал белый 1
# квадрат чёрный 2
# ромб серый 3

# %% [markdown]
# ![14.jpg](data:image/jpeg;base64,...)

# %%
class Figure:
  color = "white"
  def changecolor(self, newcolor):
    self.color = newcolor
class oval(Figure):
  def __init__(self, length):
    self.length = length 
class Square:
  def __init__(self, length):
    self.length = length

# %% [markdown]
# ![21.jpg](data:image/jpeg;base64,...)

# %%
class Things:
  def __init__(self, n, t):
    self.namething = n
    self.total = t
th1 = Things("table", 5)   
th2 = Things("computer", 7)
print(th1.namething, th1.total) 
print(th2.namething, th2.total)
th1.color = "green"
th2.color = "black"
print(th1.color) 
print(th2.color)
# Out:
# table 5
# computer 7
# green
# black

# %% [markdown]
# Расширьте программу, создав второй подкласс класса Table, содержащий пару методов, отличающихся от методов класса Kitchen().

# %%
class Table:
  def __init__(self, l, w, h):
    self.long=l
    self.width=w
    self.height=h
  def outing(self):
    print(self.long, self.width, self.height)
class Kitchen(Table):
  def howplaces(self, n):
    if n<2:
      print("It is not kitchen table")
    else:
      self.places=n
  def outplaces(self):
        print(self.places)
class Worker(Table):
  def newsize(self, new_long, new_width, new_height):
    self.new_long=new_long
    self.new_width=new_width
    self.new_height=new_height
t_room1=Kitchen(2, 1, 0.5)
t_room1.outing()
t_room1.howplaces(5)
t_room1.outplaces()
t_room2=Table(1, 3, 0.7)
t_room2.outing()
t_room3=Worker(2, 3, 0.4)
t_room3.outing()
t_room3.newsize(1, 4, 0.5)
# Out:
# 2 1 0.5
# 5
# 1 3 0.7
# 2 3 0.4
